# %%
# Importing the libraries
import os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Peek into the data by creating pandas dataframe
star_df = pd.read_csv('data/cleaned_star_data.csv')
star_df.sample(10) # Random 10 samples from star_df
# Out:
#      Temperature (K)  Luminosity(L/Lo)  Radius(R/Ro)  Absolute magnitude(Mv)  \
# 141            21020           0.00150        0.0112                   11.52
# 83             17200           0.00098        0.0150                   12.45
# 103            17120      235000.00000       83.0000                   -6.89
# 89             19860           0.00110        0.0131                   11.34
# 32             15276        1136.00000        7.2000                   -1.97
# 7               2600           0.00040        0.0960                   17.40
# 41              3365      340000.00000       23.0000                   -6.20
# 6               2637           0.00073        0.1270                   17.22
# 51              3750      283000.00000     1260.0000                   -7.63
# 230            24145      382993.00000     1494.0000                   -8.84
#
#      Star type  Star color Spectral Class
# 141          2        Blue              B
# 83           2  Blue-White              B
# 103          4        Blue              O
# 89           2        Blue              B
# 32           3  Blue-White              B
# 7            0         Red              M
# 41           4         Red              M
# 6            0         Red              M
# 51           5         Red              M
# 230          5  Blue-White              B

# %%
# Check general information about the dataframe
star_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240 entries, 0 to 239
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Temperature (K)         240 non-null    int64
#  1   Luminosity(L/Lo)        240 non-null    float64
#  2   Radius(R/Ro)            240 non-null    float64
#  3   Absolute magnitude(Mv)  240 non-null    float64
#  4   Star type               240 non-null    int64
#  5   Star color              240 non-null    object
#  6   Spectral Class          240 non-null    object
# dtypes: float64(3), int64(2), object(2)
# memory usage: 13.3+ KB

# %% [markdown]
# ### Observations
# **1)** Dataset consists of 240 rows, 6 feature and 1 target columns,
# - *Absolute Temperature (in K)*
# - *Relative Luminosity (L/Lo)*
# - *Relative Radius (R/Ro)*
# - *Absolute Magnitude (Mv)*
# - *Star Color*
# - *Spectral Class*
# - *Star Type (Target classes)*
#
# Here,
# - *Lo = 3.828 x 10^26 Watts (Avg Luminosity of Sun)*
# - *Ro = 6.9551 x 10^8 m (Avg Radius of Sun)*
#
# **2)** Two categorical features (object type) which will need some kind of encoding,
# - *Star Color*
# - *Spectral Class*
#
# **3)** It consists of some different features of stars. Information on the star type is given below,
# - **0** → Brown Dwarf
# - **1** → Red Dwarf
# - **2** → White Dwarf
# - **3** → Main Sequence
# - **4** → Supergiants
# - **5** → Hypergiants
